# %%
from langchain_gigachat.chat_models import GigaChat
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser, PydanticOutputParser
from langchain_core.runnables import RunnableSequence
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import json
import re
pd.set_option('display.max_colwidth', 1000)

# %%
llm = GigaChat(
credentials="OGRmN2Q5OWEtOTQ4Mi00N2FmLWFmNjgtYTYwZGI5ZmZmYjhmOmVjOTkwNGZkLTFlOTctNGZhYy05MmY2LWViZDJhMDIyNjBhZA==",
scope="GIGACHAT_API_PERS", # или GIGACHAT_API_CORP для юридических лиц
model="GigaChat-2", # можно указать конкретную версию, по умолчанию Lite
verify_ssl_certs=False,
streaming=True, # включение потоковой передачи
temperature=0.2, # настройка креативности
max_tokens=1000 # максимальная длина ответа
)
# Проверка подключения
response = llm.invoke("Привет! Как дела?")
print(response.content)
# Out:
# Привет! Всё отлично, готов общаться и помогать тебе с любыми вопросами. А ты как настроение держишь сегодня?

# %%
df1 = pd.read_csv(r'rental_applications_amount.csv') # С разметкой
df2 = pd.read_csv(r'rental_applications_text.csv', delimiter=';') # Без разметки
df1_to_test_= df1[:20] # 20 наблюдений для проверки количества взрослых/детей
df1_to_test_['count_adults'] = [1, 5, 4, 2, 3, 2, 2, 2, 3, 1, 2, 2, 2, 2, 2, 4, 2, 2, 2, 6]
df1_to_test_['count_children'] = [0, 0, 3,  1, 3, 0, 0, 2, 1, 2, 2, 1, 3, 3, 4, 0, 0, 2, 0, 0]
# Out:
# C:\Users\gromo\AppData\Local\Temp\ipykernel_5980\4050383508.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_to_test_['count_adults'] = [1, 5, 4, 2, 3, 2, 2, 2, 3, 1, 2, 2, 2, 2, 2, 4, 2, 2, 2, 6]
# C:\Users\gromo\AppData\Local\Temp\ipykernel_5980\4050383508.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_to_test_['count_children'] = [0, 0, 3,  1, 3, 0, 0, 2, 1, 2, 2, 1, 3, 3, 4, 0, 0, 2, 0, 0]

# %%
json_schema = {
    "type": "object",
    "properties": {
        "total_persons": {"type": "integer"},
        "count_adults": {"type": "integer"},
        "count_children": {"type": "integer"}
    },
    "required": ["total_persons", "count_adults", "count_children"],
    "additionalProperties": False
}

# %%
# Простой промпт для извлечения количества людей
system_message = SystemMessage(content="""
ы - эксперт по анализу текстовых заявок на аренду жилья. Проанализируй следующий текст заявки на аренду жилья и извлеки количество человек, которые будут проживать.

Текст заявки: {text}

Верни 3 числа (целые числа), соответствующее количеству проживающих  (для всех записей), количеству проживающих взрослых людей (для первых 20 записей), количество проживающих детей (для первых 20 записей).
Если количество не указано явно, постарайся определить его по контексту, где не указан возраст ребенка или явного указания их количества то значит в заявки нет детей.

Запиши в json-схему по очереди total_persons - общее количество людей, count_adults - количество взрослых людей, count_children - количество детей:"""
)

human_template = """Текст заявки: {text}

Проанализируй текст и верни JSON с количеством проживающих:"""

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", system_message.content),
    ("human", human_template)
])

# %%
# Создание цепочки
chain = prompt | llm

# Функция для извлечения JSON из ответа
def extract_json_from_response(response):
    try:
        json_match = re.search(r'\{.*\}', response.content, re.DOTALL)
        if json_match:
            return json.loads(json_match.group())
        else:
            return json.loads(response.content)
    except json.JSONDecodeError:
        print(f"Ошибка парсинга JSON: {response.content}")
        return {"total_persons": None, "count_adults": None, "count_children": None}

# %%
# Обработка данных и создание результатов
results = []

for idx, row in df2.iterrows():
    try:
        # Получение ответа от модели
        response = chain.invoke({"text": row['text']})
        
        # Извлечение JSON
        result_json = extract_json_from_response(response)
        
        # Поиск соответствующей разметки
        true_data = df1[df1['text_id'] == row['text_id']]
        true_amount = true_data['amount'].values[0] if not true_data.empty else None
        
        # Создание записи результата
        result_row = {
            'text_id': row['text_id'],
            'predicted_total_persons': result_json.get('total_persons'),
            'true_total_persons': true_amount,
            'correct': result_json.get('total_persons') == true_amount if true_amount is not None else None,
            'predicted_adults': result_json.get('count_adults'),
            'predicted_children': result_json.get('count_children')
        }
        
        results.append(result_row)
        
        print(f"Обработана запись {idx+1}/{len(df2)}: {result_row}")
        
    except Exception as e:
        print(f"Ошибка при обработке text_id {row['text_id']}: {str(e)}")
        results.append({
            'text_id': row['text_id'],
            'predicted_total_persons': None,
            'true_total_persons': None,
            'correct': None,
            'predicted_adults': None,
            'predicted_children': None
        })
# Out:
# Обработана запись 1/100: {'text_id': 14205200, 'predicted_total_persons': 1, 'true_total_persons': np.int64(1), 'correct': np.True_, 'predicted_adults': 1, 'predicted_children': 0}
# Обработана запись 2/100: {'text_id': 319097075, 'predicted_total_persons': 8, 'true_total_persons': np.int64(5), 'correct': np.False_, 'predicted_adults': 5, 'predicted_children': 3}
# Обработана запись 3/100: {'text_id': 98881311, 'predicted_total_persons': 7, 'true_total_persons': np.int64(7), 'correct': np.True_, 'predicted_adults': 4, 'predicted_children': 3}
# Обработана запись 4/100: {'text_id': 44587027, 'predicted_total_persons': 6, 'true_total_persons': np.int64(6), 'correct': np.True_, 'predicted_adults': 4, 'predicted_children': 2}
# Обработана запись 5/100: {'text_id': 352802829, 'predicted_total_persons': 6, 'true_total_persons': np.int64(6), 'correct': np.True_, 'predicted_adults': 3, 'predicted_children': 3}
# Обработана запись 6/100: {'text_id': 52157605, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 7/100: {'text_id': 408430986, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 8/100: {'text_id': 176294447, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 9/100: {'text_id': 150296790, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 3, 'predicted_children': 1}
# Обработана запись 10/100: {'text_id': 120627580, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 1, 'predicted_children': 2}
# Обработана запись 11/100: {'text_id': 447606306, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 12/100: {'text_id': 6705832, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 13/100: {'text_id': 98410800, 'predicted_total_persons': 5, 'true_total_persons': np.int64(5), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 3}
# Обработана запись 14/100: {'text_id': 89356440, 'predicted_total_persons': 5, 'true_total_persons': np.int64(5), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 3}
# Обработана запись 15/100: {'text_id': 8267186, 'predicted_total_persons': 6, 'true_total_persons': np.int64(6), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 4}
# Обработана запись 16/100: {'text_id': 12546114, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 4, 'predicted_children': 0}
# Обработана запись 17/100: {'text_id': 127719493, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 18/100: {'text_id': 65977922, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 19/100: {'text_id': 58833820, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 20/100: {'text_id': 42581032, 'predicted_total_persons': 6, 'true_total_persons': np.int64(6), 'correct': np.True_, 'predicted_adults': None, 'predicted_children': None}
# Обработана запись 21/100: {'text_id': -158709235, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 22/100: {'text_id': 109591148, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 4, 'predicted_children': 0}
# Обработана запись 23/100: {'text_id': 98770155, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 24/100: {'text_id': 123854173, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 25/100: {'text_id': 28102570, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 3, 'predicted_children': 0}
# Обработана запись 26/100: {'text_id': 1253439, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 27/100: {'text_id': 409704480, 'predicted_total_persons': 6, 'true_total_persons': np.int64(6), 'correct': np.True_, 'predicted_adults': 4, 'predicted_children': 2}
# Обработана запись 28/100: {'text_id': 112939206, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 29/100: {'text_id': 6622223, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': None, 'predicted_children': None}
# Обработана запись 30/100: {'text_id': 45915115, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 31/100: {'text_id': 28995748, 'predicted_total_persons': 6, 'true_total_persons': np.int64(6), 'correct': np.True_, 'predicted_adults': 3, 'predicted_children': 3}
# Обработана запись 32/100: {'text_id': 137402178, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 33/100: {'text_id': 17343293, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 34/100: {'text_id': 20755551, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 35/100: {'text_id': 154176552, 'predicted_total_persons': 8, 'true_total_persons': np.int64(8), 'correct': np.True_, 'predicted_adults': 4, 'predicted_children': 4}
# Обработана запись 36/100: {'text_id': 436988893, 'predicted_total_persons': 1, 'true_total_persons': np.int64(1), 'correct': np.True_, 'predicted_adults': 1, 'predicted_children': 0}
# Обработана запись 37/100: {'text_id': 116954663, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 38/100: {'text_id': 82784856, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 1, 'predicted_children': 1}
# Обработана запись 39/100: {'text_id': 394028741, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 40/100: {'text_id': 143782331, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': None, 'predicted_children': None}
# Обработана запись 41/100: {'text_id': 165421719, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 42/100: {'text_id': 7602210, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 43/100: {'text_id': 72702202, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 44/100: {'text_id': 24429619, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': None, 'predicted_children': None}
# Обработана запись 45/100: {'text_id': 204925103, 'predicted_total_persons': 6, 'true_total_persons': np.int64(6), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 4}
# Обработана запись 46/100: {'text_id': 245617104, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 47/100: {'text_id': 131617606, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 48/100: {'text_id': 13769140, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 4, 'predicted_children': 0}
# Обработана запись 49/100: {'text_id': 136293583, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 50/100: {'text_id': 219105839, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 3, 'predicted_children': 0}
# Обработана запись 51/100: {'text_id': 359673002, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 3, 'predicted_children': 0}
# Обработана запись 52/100: {'text_id': 258222164, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 53/100: {'text_id': 470788217, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 54/100: {'text_id': 214627751, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 55/100: {'text_id': 68345567, 'predicted_total_persons': 8, 'true_total_persons': np.int64(4), 'correct': np.False_, 'predicted_adults': None, 'predicted_children': None}
# Обработана запись 56/100: {'text_id': 477872593, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 57/100: {'text_id': 29646178, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 1, 'predicted_children': 1}
# Обработана запись 58/100: {'text_id': 54215543, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 59/100: {'text_id': 37583310, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 60/100: {'text_id': 145108184, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 1, 'predicted_children': 1}
# Обработана запись 61/100: {'text_id': 84564596, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 62/100: {'text_id': 17027538, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 63/100: {'text_id': 223485927, 'predicted_total_persons': 11, 'true_total_persons': np.int64(11), 'correct': np.True_, 'predicted_adults': 6, 'predicted_children': 5}
# Обработана запись 64/100: {'text_id': 78108095, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 65/100: {'text_id': 86482847, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 66/100: {'text_id': 24824783, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 67/100: {'text_id': 255826470, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 68/100: {'text_id': 137033136, 'predicted_total_persons': 5, 'true_total_persons': np.int64(5), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 3}
# Обработана запись 69/100: {'text_id': 17642481, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 70/100: {'text_id': 14837379, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 71/100: {'text_id': 79737918, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 72/100: {'text_id': 5596251, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 73/100: {'text_id': 49704706, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': None, 'predicted_children': None}
# Обработана запись 74/100: {'text_id': 39677362, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 75/100: {'text_id': 339982855, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 76/100: {'text_id': 16515566, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 77/100: {'text_id': 154900963, 'predicted_total_persons': 5, 'true_total_persons': np.int64(5), 'correct': np.True_, 'predicted_adults': 3, 'predicted_children': 2}
# Обработана запись 78/100: {'text_id': 237679797, 'predicted_total_persons': 1, 'true_total_persons': np.int64(1), 'correct': np.True_, 'predicted_adults': 1, 'predicted_children': 0}
# Обработана запись 79/100: {'text_id': 69438266, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 80/100: {'text_id': 3015738, 'predicted_total_persons': 1, 'true_total_persons': np.int64(1), 'correct': np.True_, 'predicted_adults': 1, 'predicted_children': 0}
# Обработана запись 81/100: {'text_id': 414557480, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 82/100: {'text_id': 31701880, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 83/100: {'text_id': 144045291, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 84/100: {'text_id': 71882262, 'predicted_total_persons': 1, 'true_total_persons': np.int64(1), 'correct': np.True_, 'predicted_adults': 1, 'predicted_children': 0}
# Обработана запись 85/100: {'text_id': 296021803, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': None, 'predicted_children': None}
# Обработана запись 86/100: {'text_id': 162173888, 'predicted_total_persons': 7, 'true_total_persons': np.int64(7), 'correct': np.True_, 'predicted_adults': 3, 'predicted_children': 4}
# Обработана запись 87/100: {'text_id': 228328421, 'predicted_total_persons': 5, 'true_total_persons': np.int64(5), 'correct': np.True_, 'predicted_adults': 3, 'predicted_children': 2}
# Обработана запись 88/100: {'text_id': 9890691, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 2}
# Обработана запись 89/100: {'text_id': 399249920, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 90/100: {'text_id': 316530114, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 1}
# Обработана запись 91/100: {'text_id': 514036726, 'predicted_total_persons': 7, 'true_total_persons': np.int64(7), 'correct': np.True_, 'predicted_adults': 5, 'predicted_children': 2}
# Обработана запись 92/100: {'text_id': 364570867, 'predicted_total_persons': 5, 'true_total_persons': np.int64(5), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 3}
# Обработана запись 93/100: {'text_id': 34710969, 'predicted_total_persons': 5, 'true_total_persons': np.int64(5), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 3}
# Обработана запись 94/100: {'text_id': 18711532, 'predicted_total_persons': 4, 'true_total_persons': np.int64(4), 'correct': np.True_, 'predicted_adults': 3, 'predicted_children': 1}
# Обработана запись 95/100: {'text_id': 129035061, 'predicted_total_persons': 12, 'true_total_persons': np.int64(12), 'correct': np.True_, 'predicted_adults': 7, 'predicted_children': 5}
# Обработана запись 96/100: {'text_id': 233661411, 'predicted_total_persons': 9, 'true_total_persons': np.int64(9), 'correct': np.True_, 'predicted_adults': 4, 'predicted_children': 5}
# Обработана запись 97/100: {'text_id': 77792435, 'predicted_total_persons': 1, 'true_total_persons': np.int64(1), 'correct': np.True_, 'predicted_adults': 1, 'predicted_children': 0}
# Обработана запись 98/100: {'text_id': 102311098, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': 2, 'predicted_children': 0}
# Обработана запись 99/100: {'text_id': 123993850, 'predicted_total_persons': 2, 'true_total_persons': np.int64(2), 'correct': np.True_, 'predicted_adults': None, 'predicted_children': None}
# Обработана запись 100/100: {'text_id': 54495881, 'predicted_total_persons': 3, 'true_total_persons': np.int64(3), 'correct': np.True_, 'predicted_adults': None, 'predicted_children': None}

# %%
results_df = pd.DataFrame(results)
# Сохранение результатов
results_df.to_csv('results.csv', index=False, encoding='utf-8')

# %%
results_df
# Out:
#       text_id  predicted_total_persons  true_total_persons  correct  \
# 0    14205200                        1                   1     True
# 1   319097075                        8                   5    False
# 2    98881311                        7                   7     True
# 3    44587027                        6                   6     True
# 4   352802829                        6                   6     True
# ..        ...                      ...                 ...      ...
# 95  233661411                        9                   9     True
# 96   77792435                        1                   1     True
# 97  102311098                        2                   2     True
# 98  123993850                        2                   2     True
# 99   54495881                        3                   3     True
#
#     predicted_adults  predicted_children
# 0                1.0                 0.0
# 1                5.0                 3.0
# 2                4.0                 3.0
# 3                4.0                 2.0
# 4                3.0                 3.0
# ..               ...                 ...
# 95               4.0                 5.0
# 96               1.0                 0.0
# 97               2.0                 0.0
# 98               NaN                 NaN
# 99               NaN                 NaN
#
# [100 rows x 6 columns]

# %%
print("\nПримеры JSON ответов для 5 заявок:")
for i in range(min(5, len(results))):
    print(f"Заявка {i+1}: {results[i]}")
# Out:
# Примеры JSON ответов для 5 заявок:
# Заявка 1: {'text_id': 14205200, 'predicted_total_persons': 1, 'true_total_persons': np.int64(1), 'correct': np.True_, 'predicted_adults': 1, 'predicted_children': 0}
# Заявка 2: {'text_id': 319097075, 'predicted_total_persons': 8, 'true_total_persons': np.int64(5), 'correct': np.False_, 'predicted_adults': 5, 'predicted_children': 3}
# Заявка 3: {'text_id': 98881311, 'predicted_total_persons': 7, 'true_total_persons': np.int64(7), 'correct': np.True_, 'predicted_adults': 4, 'predicted_children': 3}
# Заявка 4: {'text_id': 44587027, 'predicted_total_persons': 6, 'true_total_persons': np.int64(6), 'correct': np.True_, 'predicted_adults': 4, 'predicted_children': 2}
# Заявка 5: {'text_id': 352802829, 'predicted_total_persons': 6, 'true_total_persons': np.int64(6), 'correct': np.True_, 'predicted_adults': 3, 'predicted_children': 3}

# %%
valid_results = results_df.dropna(subset=['predicted_total_persons', 'true_total_persons'])
accuracy_true_total_person = accuracy_score(valid_results['true_total_persons'], valid_results['predicted_total_persons'])

print("Точность по общему количеству людей:",round(accuracy_true_total_person, 2))
# Out:
# Точность по общему количеству людей: 0.98

# %%
accuracy_adults = accuracy_score(df1_to_test_['count_adults'][:19], results_df['predicted_adults'][:19])

print("Точность по взрослым:",round(accuracy_adults, 2))
# Out:
# Точность по взрослым: 0.95

# %%
accuracy_children = accuracy_score(df1_to_test_['count_children'][:19], results_df['predicted_children'][:19])

print("Точность по детям:",round(accuracy_children, 2))
# Out:
# Точность по детям: 0.89
